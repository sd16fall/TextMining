# %%
from pattern.web import *
import string

Rembrandt=URL("http://www.gutenberg.org/cache/epub/17215/pg17215.txt").download()



                
def counting(abc):
    dic = dict()
    count = abc
    for word in count.split():
        pureword = word.replace("-"," ")
        morepureword = pureword.strip(string.punctuation + string.whitespace)
        morepureword = morepureword.lower()
        if morepureword in dic:
            dic[morepureword] += 1
        else:
            dic [morepureword] = 1
    order=[]
    for key in dic:
        order.append((dic[key],key))
    order.sort(reverse=True)
    for (frequency,key) in order:
        print key
    
    
    
    

counting(Rembrandt)
# Out:
# the
# of
# and
# a
# to
# in
# his
# he
# that
# was
# with
# or
# is
# at
# rembrandt
# it
# by
# as
# this
# for
#
# you
# project
# not
# an
# but
# work
# him
# from
# are
# had
# be
# gutenberg tm
# all
# have
# so
# on
# which
# one
# any
# we
# pictures
# who
# when
# works
# rembrandt's
# upon
# has
# picture
# portrait
# i
# were
# life
# if
# painted
# old
# her
# other
# can
# our
# gutenberg
# before
# what
# man
# about
# art
# them
# their
# electronic
# they
# etchings
# do
# been
# himself
# could
# through
# there
# may
# face
# these
# st
# no
# hermitage
# foundation
# would
# world
# terms
# only
# full
# did
# petersburg
# most
# into
# gallery
# us
# two
# see
# christ
# years
# way
# such
# states
# should
# painting
# master
# light
# great
# agreement
# under
# some
# painter
# m
# illustration
# day
# called
# book
# mother
# many
# little
# license
# its
# every
# amsterdam
# without
# will
# public
# perhaps
# now
# night
# national
# must
# more
# ...

# %%
from pattern.web import *
import string

Michaelangelo=URL("http://www.gutenberg.org/cache/epub/11242/pg11242.txt").download()



                
def counting(abc):
    dic = dict()
    count = abc
    for word in count.split():
        pureword = word.replace("-"," ")
        morepureword = pureword.strip(string.punctuation + string.whitespace)
        morepureword = morepureword.lower()
        if morepureword in dic:
            dic[morepureword] += 1
        else:
            dic [morepureword] = 1
    order=[]
    for key in dic:
        order.append((dic[key],key))
    order.sort(reverse=True)
    for (frequency,key) in order:
        print key
    
    
    
    

counting(Michaelangelo)
# Out:
# the
# of
# to
# and
# in
# a
# his
# that
# he
# i
# it
# with
# for
# was
# is
# this
# by
# as
# have
# which
# not
# at
# be
# michelangelo
# from
# you
# on
# him
# had
# but
# we
# upon
# so
# or
# been
# all
# one
# who
# are
# me
# my
# when
# were
# what
# an
# may
# has
# work
# their
# they
# these
# no
# florence
# michelangelo's
# some
# more
# will
# if
# your
# do
# would
# s
# rome
# there
# them
# about
# than
# man
# now
# its
# great
# life
# into
# own
# two
# time
# pope
# letter
# only
# made
# other
# should
# out
# must
# any
# after
# then
# could
# also
# up
# art
# her
# years
# first
# like
# am
# same
# those
# did
# while
# most
# very
# such
# still
# our
# old
# left
# being
# vasari
# much
# buonarroti
# men
# know
# through
# can
# here
# us
# julius
# shall
# without
# last
# death
# said
# hand
# himself
# whole
# certain
# good
# both
# before
# because
# many
# make
# well
# under
# might
# nothing
# during
# sent
# marble
# lorenzo
# how
# see
# ...

# %%
'''
Project overview:
    For this project I've decided to compare two books about two famous artist Michelangelo and Rembrandt. I've decided
    to see what the top ten words were fore these two books in order to see if there is a difference in the ideas and
    styles between both artists that might be significant.
    
Implementation:
    I've used the dictionary method to set a value to all the words according to the frequency of the word appearing in
    the text. By using the plain txt URLs in Gutenberg, I've downloaded the text rom there and strip all the punctuation
    and whitespace. Then from that by assinging values to the keys in the dictionary, it was able to product a list of 
    words sorted through the most frequent word to less.

Results:
    The top ten significant words in the text describing Michelangelo are: Florence, Rome, life, pope, letter, old,
    vasari, buonarroti, Julius, death, hand. And the top ten significant words in the text describing Rembrandt are:
    pictures, portrait, life, painted, etching, electronic, face, hermitage, world, petersburg. From this you can argue
    that location played a big influence in Michelangelo's work. Furthremore, the lives of the people around him also 
    has huge influence towards shaping his art style. His work seemed to have more of a symbolism purpose behind it. In
    comparison, Rembrandt's work seem to mainly focus on human portraits. He did not seem to be an emotional or lively 
    person. Location did not seem to have a huge effect on his work and he seemed more focused on practicing his skills
    which led him to success. Therefore, the words show how both artists has different personalities and what influenced
    their work that led them to success.
    
Reflection:
    The textbook was really helpful in helping to come up with the code to analyze this text. At first I was struggling
    to assign and sort the value as well as my computer was having a hard time processing the text. However, after 
    reading chapter 12 and 13 of Think Python and looking at the toolbox project for data mining/analysis it made it
    easier by giving me the idea of using dictionary and assigning the count of each word to the value of the key.

'''
