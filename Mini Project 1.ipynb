# %%
from pattern.web import Twitter

debates = Twitter()
i = None
debatestweets=[]
for j in range(3):
    for tweet in debates.search('\debates', start=i, count=100):
        debatestweets.append(tweet.text)
        i = tweet.id
        
import pickle

f = open('tweetdebates.pickle', 'w')
pickle.dump(debatestweets,f)
f.close()

input_file = open('tweetdebates.pickle', 'r')
reloaded_debates_tweets = pickle.load(input_file)

# %%
import indicoio
indicoio.config.api_key = '6fde4cbb37c9180400dc259ad8c7b897'

# single example
sent = indicoio.sentiment_hq(reloaded_debates_tweets)

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

#flip list
sent.reverse()

x_axis = []
c = 0

for i in sent:
    x_axis.append(c)
    c += 1

plt.plot(x_axis, sent)
